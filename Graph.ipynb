# %% [markdown]
# <a href="https://colab.research.google.com/github/XGHouFTW/ISEF-2022/blob/main/Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/ISEF/Datasets/GraphEssentials.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dfessential = pd.read_csv(path)
fig, ax1 = plt.subplots()
ax1.set_xlabel("Date")
ax1.set_ylabel("BTC Price")
ax1.plot(dfessential['Date'], dfessential["BTC Daily Price"], color = "tab:red")

ax2 = ax1.twinx()
ax2.set_xlabel("Date")
ax2.set_ylabel("BTC Tweets Compound")
ax2.plot(dfessential['Date'], dfessential["BTC Tweets Compound"], color = "tab:blue")
fig.tight_layout()
plt.show()
